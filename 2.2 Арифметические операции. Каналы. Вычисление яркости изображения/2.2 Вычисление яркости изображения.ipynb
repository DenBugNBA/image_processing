# %%
from skimage.io import imread, imsave, imshow

# %%
from skimage.color import rgb2gray

# %%
img = imread('tiger-color.png')

# %%
img_gray = rgb2gray(img)

# %%
img_gray.shape
# Out:
# (600, 800)

# %%
imshow(img_gray);

# %%
img_gray1 = imread('tiger-color.png', 1) # сразу считать серое изображение

# %%
import numpy as np

# %%
np.array_equal(img_gray, img_gray1)
# Out:
# True
