# %%
# %matplotlib inline # чтобы просматривать изображения в бразуере

# %%
from skimage.io import imread, imshow, imsave

# %%
img = imread('tiger-color.png')

# %%
imshow(img);

# %%
img.shape # 750 строк, 1200 столбцов, 3 канала
# Out:
# (750, 1200, 3)

# %%
img.shape[1] # ширина изображения
# Out:
# 1200

# %%
img[383, 374] # uint8 - целый беззнаковый тип, который помещается в 8 бит или 1 байт, от 0 до 255
# Out:
# array([186, 128,  46], dtype=uint8)

# %%
img[383, 374, 2] # синяя компонента пикселя
# Out:
# 46

# %%
img[383, 374] = [255, 255, 0]

# %%
imsave('tiger-yellow-pixel.png', img)
