# %%
from skimage.io import imread, imsave, imshow

# %%
img = imread('tiger-color1.png')

# %%
nose = img[370:410, 350:440]

# %%
imshow(nose);

# %%
img[370:410, 350:440] = [255, 0, 255]

# %%
imshow(img);

# %%
img_yellow = imread('tiger-yellow-pixel.png')

# %%
imshow(img_yellow[370:410, 350:440]);

# %%
img_assigned = img_yellow # ссылка на изображение

# %%
img_copy = img_yellow.copy() # копирование

# %%
img_yellow[370:410, 350:440] = [255, 0, 255]

# %%
imshow(img_yellow);

# %%
imshow(img_assigned);

# %%
imshow(img_copy);
